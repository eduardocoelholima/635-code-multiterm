# %% [markdown]
# ```
# This assignment involves working with a 200-sample synthetic data to perform
# binary classification using a regularized logistic regression model.
#
# Submit using mycourses dropbox. Save the file in ipynb format
# Your submission will be shared with all your classmates.
#
# You are allowed to research code online or use LLM code generators.
#
# Requirements:
#
# 1. Load the data (code provided) and show the shape of the numpy ndarray.
# 2. Plot the data as a 2-D space comprised of the features, with the samples
#    colored by the associated class (3rd column in the numpy array).
# 3. Create a test split with 20% of the data. Make sure the splits are balanced
#    or stratified (e.g. the original class ratio is maintained on splits).
# 4. Implement a logistic regression model. You need to use only numpy and scipy. You can not use the already implemented Logistic Regression class from sklearn or or a similar api. Optimize the model using LMBFGS (it is fine to use any algorithm from the BFGS family and it is fine to load the optimizer from sklearn/scipy).
# 5. Present the train and test accuracy.
# 6. Train a least square model with the same train split. Compare test
#    accuracies between two models.
# 7. Compare the two models using their confusion matrices.
# 8. Plot the decision boundary of the logistic regression classifier.
# 9. Plot the data now with the two prediction regions separated by the decision
#    boundary as blue (for predicting as '0') and orange (otherwise).
# ```

# %%
import numpy as np
# !wget https://github.com/eduardocoelholima/635-code-multiterm/raw/refs/heads/main/data/binary_classification.npy
data = np.load('binary_classification.npy')
